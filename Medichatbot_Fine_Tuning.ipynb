# %% [markdown]
# <a href="https://colab.research.google.com/github/papichoolo/DSCMentalHealthChatbot/blob/main/Medichatbot_Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install huggingface_hub datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.4 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
dataset=load_dataset("sid6i7/patient-doctor",split="train")
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'Description', 'Patient', 'Doctor', 'problem_description'],
#     num_rows: 106220
# })

# %%
dataset.info
# Out:
# DatasetInfo(description='', citation='', homepage='', license='', features={'Unnamed: 0': Value(dtype='int64', id=None), 'Description': Value(dtype='string', id=None), 'Patient': Value(dtype='string', id=None), 'Doctor': Value(dtype='string', id=None), 'problem_description': Value(dtype='string', id=None)}, post_processed=None, supervised_keys=None, task_templates=None, builder_name='csv', dataset_name='patient-doctor', config_name='default', version=0.0.0, splits={'train': SplitInfo(name='train', num_bytes=163901523, num_examples=106220, shard_lengths=None, dataset_name='patient-doctor')}, download_checksums={'hf://datasets/sid6i7/patient-doctor@e19a01da8255fa52987d2339321bcb4036751c5f/data.csv': {'num_bytes': 162940981, 'checksum': None}}, download_size=162940981, post_processing_size=None, dataset_size=163901523, size_in_bytes=326842504)

# %%
# %%capture
# %pip install accelerate peft bitsandbytes transformers trl

# %%
import json
import os
from pprint import pprint
import bitsandbytes as bnb
import torch
import torch.nn as nn
import transformers
from datasets import load_dataset
from huggingface_hub import notebook_login
from peft import (
    LoraConfig,
    PeftConfig,
    PeftModel,
    get_peft_model,
    prepare_model_for_kbit_training
)
from transformers import (
    AutoConfig,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig
)

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
notebook_login()

# %% [markdown]
# Loading Model

# %%
MODEL_NAME = "meta-llama/Llama-2-7b-chat-hf"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="cuda:0",
    trust_remote_code=True,
    quantization_config=bnb_config
)

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
device="cuda:0"

# %% [markdown]
# Setting LoRA Config

# %%
config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj","v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)

# %% [markdown]
# Generating Prompt based on Dataset

# %%
def generate_prompt(data_point):
  return f""" <<SYS>> You are a helpful and honest medical assistant, you will only answer the human in the prompt and help them out in their medical problems
  [INST]<human>: {data_point["Patient"]}[/INST]<</SYS>>
<assistant>: {data_point["Doctor"]}
""".strip()

def generate_and_tokenize_prompt(data_point):
  full_prompt = generate_prompt(data_point)
  tokenized_full_prompt = tokenizer(full_prompt, padding=True, truncation=True)
  return tokenized_full_prompt

# %%
data = dataset.shuffle().map(generate_and_tokenize_prompt)
# Out:
# Map:   0%|          | 0/106220 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %% [markdown]
# Time to train POGGERS

# %%
training_args = transformers.TrainingArguments(
      per_device_train_batch_size=1,
      gradient_accumulation_steps=4,
      max_steps=40,
      num_train_epochs=1,
      learning_rate=2e-4,
      fp16=True,
      save_total_limit=3,
      logging_steps=1,
      output_dir="experiments",
      optim="paged_adamw_8bit",
      lr_scheduler_type="cosine",
      warmup_ratio=0.05,
)

trainer = transformers.Trainer(
    model=model,
    train_dataset=data,
    args=training_args,
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = False
trainer.train()
# Out:
#     <div>
#
#       <progress value='32' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/40 04:04 < 01:05, 0.12 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.912400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.084800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.835300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.448800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.415700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.551700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.544600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.712100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.492200</td>
#     </tr>
#     <tr>
# ...

# %%
model.save_pretrained("trained-model")

# %%
PEFT_MODEL = "tmberooney/medllama"

model.push_to_hub(
    PEFT_MODEL, use_auth_token=True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:853: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# adapter_model.safetensors:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/tmberooney/medllama/commit/5c94422b0d7c712dc4f7e9cc4a38b963f7f1502f', commit_message='Upload model', commit_description='', oid='5c94422b0d7c712dc4f7e9cc4a38b963f7f1502f', pr_url=None, pr_revision=None, pr_num=None)

# %%
config = PeftConfig.from_pretrained(PEFT_MODEL)
model = AutoModelForCausalLM.from_pretrained(
    config.base_model_name_or_path,
    return_dict=True,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True
)

tokenizer=AutoTokenizer.from_pretrained(config.base_model_name_or_path)
tokenizer.pad_token = tokenizer.eos_token

model = PeftModel.from_pretrained(model, PEFT_MODEL)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/33.6M [00:00<?, ?B/s]

# %%
def cut_off_text(text, prompt):
    cutoff_phrase = prompt
    index = text.find(cutoff_phrase)
    if index != -1:
        return text[:index]
    else:
        return text

def remove_substring(string, substring):
    return string.replace(substring, "")

# %%
generation_config = model.generation_config
generation_config.max_new_tokens = 500
generation_config.temperature = 0.7
generation_config.top_p = 0.7
generation_config.num_return_sequences = 1
generation_config.pad_token_id = tokenizer.eos_token_id
generation_config.eos_token_id = tokenizer.eos_token_id

# %%
# %%time
device = "cuda:0"

prompt = """
[INST]<human>: Paracetamol doesnt work in reducing my fever what should i Do?[/INST]
<assistant>:
""".strip()

encoding = tokenizer(prompt, return_tensors="pt").to(device)
with torch.inference_mode():
  outputs = model.generate(
      input_ids = encoding.input_ids,
      attention_mask = encoding.attention_mask,
      generation_config = generation_config
  )
final_outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
final_outputs = cut_off_text(final_outputs, '\n<human>: ')
final_outputs = remove_substring(final_outputs, prompt)

print(final_outputs)
# Out:
#  Hi there! I'm sorry to hear that paracetamol isn't working for you. There are a few things you could try:
#
# 1. Take it for a longer period of time: Paracetamol can take a while to start working, so you may need to take it for a few days before you start feeling better.
# 2. Take a higher dose: If you're taking a low dose of paracetamol, you could try increasing it to see if that helps. However, be careful not to overdo it, as this can cause side effects.
# 3. Try a different medication: If paracetamol isn't working for you, you could try taking ibuprofen or aspirin instead. These medications work in a similar way to paracetamol, but may be more effective for some people.
# 4. See a doctor: If you're still feeling unwell after a few days of taking paracetamol, you may want to see a doctor. They can check if you have an underlying infection or other condition that needs to be treated.
#
# I hope this helps! Let me know if you have any other questions.
#
# ...

# %% [markdown]
# # Using GPTQ trained model

# %%
# !pip install -q -U optimum
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 403.3/403.3 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.0 MB/s eta 0:00:00

# %%
# !pip install auto-gptq --extra-index-url https://huggingface.github.io/autogptq-index/whl/cu117/
# Out:
# Looking in indexes: https://pypi.org/simple, https://huggingface.github.io/autogptq-index/whl/cu117/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 36.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 92.1 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id1 = "TheBloke/Mistral-7B-Instruct-v0.2-DARE-GPTQ"
model1 = AutoModelForCausalLM.from_pretrained(model_id1, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id1)
# Out:
# model.safetensors:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
print(model1)
# Out:
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (rotary_emb): MistralRotaryEmbedding()
#           (k_proj): QuantLinear()
#           (o_proj): QuantLinear()
#           (q_proj): QuantLinear()
#           (v_proj): QuantLinear()
#         )
#         (mlp): MistralMLP(
#           (act_fn): SiLUActivation()
#           (down_proj): QuantLinear()
#           (gate_proj): QuantLinear()
#           (up_proj): QuantLinear()
#         )
#         (input_layernorm): MistralRMSNorm()
#         (post_attention_layernorm): MistralRMSNorm()
#       )
#     )
#     (norm): MistralRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
model1.config.quantization_config.to_dict()
# Out:
# {'quant_method': <QuantizationMethod.GPTQ: 'gptq'>,
#  'bits': 4,
#  'tokenizer': None,
#  'dataset': None,
#  'group_size': 128,
#  'damp_percent': 0.1,
#  'desc_act': True,
#  'sym': True,
#  'true_sequential': True,
#  'use_cuda_fp16': False,
#  'model_seqlen': None,
#  'block_name_to_quantize': None,
#  'module_name_preceding_first_block': None,
#  'batch_size': 1,
#  'pad_token_id': None,
#  'use_exllama': True,
#  'max_input_length': None,
#  'exllama_config': {'version': <ExllamaVersion.ONE: 1>},
#  'cache_block_outputs': True}

# %%
text = "Patient: I am tummy ache. what to do? Doctor:"
inputs = tokenizer(text, return_tensors="pt").to(0)

out = model1.generate(**inputs, max_new_tokens=50)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Patient: I am tummy ache. what to do? Doctor: Tummy ache can be caused by a variety of reasons, such as indigestion, gas, constipation, food poisoning, or other medical conditions. It is important to determine the cause to provide the appropriate treatment. If the

# %%
from peft import prepare_model_for_kbit_training
from transformers import GPTQConfig


model_id1 = "TheBloke/Mistral-7B-Instruct-v0.2-DARE-GPTQ"
quantization_config_loading = GPTQConfig(bits=4, disable_exllama=True)
model1 = AutoModelForCausalLM.from_pretrained(model_id1,quantization_config=quantization_config_loading, device_map="auto")
# Out:
# Using `disable_exllama` is deprecated and will be removed in version 4.37. Use `use_exllama` instead and specify the version with `exllama_config`.The value of `use_exllama` will be overwritten by `disable_exllama` passed in `GPTQConfig` or stored in your config file.
# You passed `quantization_config` to `from_pretrained` but the model you're loading already has a `quantization_config` attribute and has already quantized weights. However, loading attributes (e.g. use_exllama, exllama_config, use_cuda_fp16, max_input_length) will be overwritten with the one you passed to `from_pretrained`. The rest will be ignored.

# %%
model1.config.quantization_config.to_dict()
# Out:
# {'quant_method': <QuantizationMethod.GPTQ: 'gptq'>,
#  'bits': 4,
#  'tokenizer': None,
#  'dataset': None,
#  'group_size': 128,
#  'damp_percent': 0.1,
#  'desc_act': True,
#  'sym': True,
#  'true_sequential': True,
#  'use_cuda_fp16': False,
#  'model_seqlen': None,
#  'block_name_to_quantize': None,
#  'module_name_preceding_first_block': None,
#  'batch_size': 1,
#  'pad_token_id': None,
#  'use_exllama': False,
#  'max_input_length': None,
#  'exllama_config': {'version': <ExllamaVersion.ONE: 1>},
#  'cache_block_outputs': True}

# %%
model1.gradient_checkpointing_enable()
model1 = prepare_model_for_kbit_training(model1)

# %%
from peft import LoraConfig, get_peft_model
config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["k_proj","o_proj","q_proj","v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model1 = get_peft_model(model1, config)
model1.print_trainable_parameters()
# Out:
# trainable params: 6,815,744 || all params: 269,225,984 || trainable%: 2.5316070532033046

# %%
from transformers import Trainer, TrainingArguments, DataCollatorForLanguageModeling

# needed for llama 2 tokenizer
tokenizer.pad_token = tokenizer.eos_token

trainer1 = Trainer(
    model=model1,
    train_dataset=data,
    args=TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=2,
        max_steps=50,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir="outputs",
        optim="adamw_hf"
    ),
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model1.config.use_cache = False  # silence the warnings. Please re-enable for inference!
trainer1.train()
# Out:
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 09:11, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.560300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.463800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.197100</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.314200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.345600</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.340900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.338200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.312600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.278700</td>
#     </tr>
#     <tr>
#       <td>10</td>
# ...

# %%
model1.save_pretrained("trained-model")

# %%
PEFT_MODEL = "tmberooney/medstralchatbotgptq"

model1.push_to_hub(
    PEFT_MODEL, use_auth_token=True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:853: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# adapter_model.safetensors:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/tmberooney/medstralchatbotgptq/commit/be6b5f21c0bad37a477ceabcb6984ec681c6a591', commit_message='Upload model', commit_description='', oid='be6b5f21c0bad37a477ceabcb6984ec681c6a591', pr_url=None, pr_revision=None, pr_num=None)

# %%
from peft import (
    LoraConfig,
    PeftConfig,
    PeftModel,
    get_peft_model,
    prepare_model_for_kbit_training
)

# %%
from transformers import BitsAndBytesConfig
import torch
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
model1 = AutoModelForCausalLM.from_pretrained(PEFT_MODEL, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(PEFT_MODEL)
# Out:
# adapter_model.safetensors:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     269     try:
# --> 270         response.raise_for_status()
#     271     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/tmberooney/medstralchatbotgptq/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# ...
